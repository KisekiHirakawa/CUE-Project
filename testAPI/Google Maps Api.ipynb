# %%
import googlemaps
import pprint # FOr printing JSON in a neat manner

key = 'AIzaSyD-O2EHGREFuCYRspG-NyRVIryB8gEhO_M' # API key
client = googlemaps.Client(key) #Create instance

geocode_result = client.geocode('東京都渋谷駅') # Keyword 
loc = geocode_result[0]['geometry']['location'] 
place_result = client.places_nearby(location=loc, radius=2000, type='train_station') # Find the type train station within radius 2000m.
# Refer to the Places API docs for more info about what types are available.
pprint.pprint(place_result)
# Out:
# {'html_attributions': [],
#  'results': [{'geometry': {'location': {'lat': 35.6580339, 'lng': 139.7016358},
#                            'viewport': {'northeast': {'lat': 35.66481580000001,
#                                                       'lng': 139.70705685},
#                                         'southwest': {'lat': 35.6528246,
#                                                       'lng': 139.69564585}}},
#               'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/generic_business-71.png',
#               'id': '21035227442c4c0d405562dc610e579e788b6b03',
#               'name': 'Shibuya Station',
#               'photos': [{'height': 3900,
#                           'html_attributions': ['<a '
#                                                 'href="https://maps.google.com/maps/contrib/103980453267432378056/photos">Tomas '
#                                                 'Hiram</a>'],
# ...

# %% [markdown]
# ### I think the following is what we need. Refer to the html_instructions.

# %%
"""
Simple Program to help you get started with Google's APIs
"""
import urllib.request, json
#Google MapsDdirections API endpoint
endpoint = 'https://maps.googleapis.com/maps/api/directions/json?'
api_key = 'AIzaSyD-O2EHGREFuCYRspG-NyRVIryB8gEhO_M'
#Asks the user to input Where they are and where they want to go.
origin = input('Where are you?: ').replace(' ','+')
destination = input('Where do you want to go?: ').replace(' ','+')
#Building the URL for the request
nav_request = 'origin={}&destination={}&key={}'.format(origin,destination,api_key)
request = endpoint + nav_request
#Sends the request and reads the response.
response = urllib.request.urlopen(request).read()
#Loads response as JSON
directions = json.loads(response)
pprint.pprint(directions)
# Out:
# Where are you?: heathrow airport
# Where do you want to go?: cambridge university
# {'geocoded_waypoints': [{'geocoder_status': 'OK',
#                          'place_id': 'ChIJ6W3FzTRydkgRZ0H2Q1VT548',
#                          'types': ['airport',
#                                    'establishment',
#                                    'point_of_interest']},
#                         {'geocoder_status': 'OK',
#                          'place_id': 'ChIJqRIn1E532EcRu7Vt86uAyiE',
#                          'types': ['establishment',
#                                    'point_of_interest',
#                                    'university']}],
#  'routes': [{'bounds': {'northeast': {'lat': 52.19975609999999,
#                                       'lng': 0.2244862},
#                         'southwest': {'lat': 51.47212039999999,
#                                       'lng': -0.5360089}},
#              'copyrights': 'Map data ©2019',
# ...
